# %%
fecha_entrega = "0113" # <<<<<<< MODIFICAR DIARIOOOO

# %%
import pandas as pd
import re
import os.path
from datetime import datetime

# %% [markdown]
# # Carga y preparación de [df]

# %%
# DataFrame
# "C:\Users\FernandoManuelGamino\Documents\4_cierre_dia_coordinadores\prueba\cedis.xlsx"
path = "../4_cierre_dia_coordinadores/"+fecha_entrega

# norte
a_file = "norte"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):
    norte = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass

# centro
a_file = "centro"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):
    centro = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass
    
# sur
a_file = "sur"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):    
    sur = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass

# puebla
a_file = "puebla"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):
    puebla = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass


# toluca
a_file = "toluca"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):    
    toluca = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass

# guadalajara
a_file = "guadalajara"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):    
    guadalajara = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass

# leon
a_file = "leon.xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):    
    leon = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass

# %%
frames = [norte, centro, sur, puebla, guadalajara, leon]

nacional = pd.concat(frames)

# %%
nacional
# Out:
#    Logistic Distributor Delivery Route Delivery Name                 Region  \
# 0     Coordinador Norte    Vdmnorte-03   Vdmnorte-03  Valle de Mexico Norte
# 1     Coordinador Norte    Vdmnorte-03   Vdmnorte-03  Valle de Mexico Norte
# 2     Coordinador Norte    Vdmnorte-03   Vdmnorte-03  Valle de Mexico Norte
# 3     Coordinador Norte    Vdmnorte-03   Vdmnorte-03  Valle de Mexico Norte
# 4     Coordinador Norte    Vdmnorte-03   Vdmnorte-03  Valle de Mexico Norte
# ..                  ...            ...           ...                    ...
# 0      Coordinador leon        Leon-05       Leon-05               PACIFICO
# 1      Coordinador leon        Leon-04       Leon-04               PACIFICO
# 2      Coordinador leon        Leon-04       Leon-04               PACIFICO
# 3      Coordinador leon        Leon-04       Leon-04               PACIFICO
# 4      Coordinador leon        Leon-04       Leon-04               PACIFICO
#
#                 City            Channel                       Sub Channel  \
# 0   Estado de Mexico  Canal Tradicional                     No manejantes
# 1   Estado de Mexico  Canal Tradicional                     No manejantes
# 2   Estado de Mexico  Canal Tradicional                     No manejantes
# 3   Estado de Mexico  Canal Tradicional                        Papelerías
# 4   Estado de Mexico  Canal Tradicional                        Papelerías
# ..               ...                ...                               ...
# 0               LEON  Canal Tradicional           Vinaterías y licorerías
# 1               LEON  Canal Tradicional                     No manejantes
# 2               LEON  Canal Tradicional  Tiendas de abarrotes/misceláneas
# 3               LEON  Canal Tradicional  Tiendas de abarrotes/misceláneas
# 4               LEON  Canal Tradicional  Tiendas de abarrotes/misceláneas
#
#                          Customer Type  Store code  \
# 0                     14_No manejantes  RB00011452
# 1                     14_No manejantes  RB00011623
# 2                     14_No manejantes  RB00011690
# 3                         7_Papelerías  MX03302008
# 4                         7_Papelerías  MX03302215
# ..                                 ...         ...
# 0           13_Vinaterías y licorerías  GT02002773
# 1                     14_No manejantes  GT02000444
# 2   8_Tiendas de abarrotes/misceláneas  GT02006523
# 3   8_Tiendas de abarrotes/misceláneas  GT02001232
# 4   8_Tiendas de abarrotes/misceláneas  GT02001351
#
#                     Store name  ...  Invoice Units Invoiced IEPS  \
# 0                   La burbuja  ...          135.0           NaN
# 1               El changarrito  ...           12.0           NaN
# 2      JARCERIA LA PROVIDENCIA  ...           14.0           NaN
# 3           PAPELERIA TERESITA  ...            6.0           NaN
# 4                    PAPELERIA  ...           12.0           NaN
# ..                         ...  ...            ...           ...
# 0                  EKOO MARKET  ...            NaN           NaN
# 1          TIENDA DE ABARROTES  ...            NaN           NaN
# 2          Abarrotes esparza 2  ...            NaN           NaN
# 3   TIENDA DE ABARROTES LUCERO  ...            NaN           NaN
# 4        ABARROTES SAN JUDITAS  ...            NaN           NaN
#
#     Invoiced IVA  Net Sales Invoice Value  Rejection %  Rejection Value  \
# 0            0.0                  1980.15    -0.000076            -0.15
# 1            0.0                      NaN     0.000000             0.00
# 2            0.0                      NaN     0.000000             0.00
# 3            0.0                      NaN     0.000000             0.00
# 4            0.0                      NaN    -0.420849           -54.50
# ..           ...                      ...          ...              ...
# 0            NaN                      NaN          NaN          -285.02
# 1            NaN                      NaN          NaN          -132.00
# 2            NaN                      NaN          NaN          -355.08
# 3            NaN                      NaN          NaN          -147.00
# 4            NaN                      NaN          NaN          -126.14
#
#     Rejection % Qty Rejection Qty  \
# 0              -0.1           -15
# 1               0.0             0
# 2               0.0             0
# 3               0.0             0
# 4              -0.2            -3
# ..              ...           ...
# 0               NaN           -27
# 1               NaN            -8
# 2               NaN           -35
# 3               NaN           -18
# 4               NaN           -20
#
#                                   Rejection Reason  visitado
# 0                                              NaN  visitado
# 1                                              NaN  visitado
# 2                     RECHAZO 10: Producto Agotado  visitado
# 3                                              NaN  visitado
# 4                                              NaN  visitado
# ..                                             ...       ...
# 0                          01 Cerrado EN la visita  visitado
# 1                RECHAZO 04: Cliente No localizado  visitado
# 2   RECHAZO 03: Producto no solicitado (No pedido)  visitado
# 3                          10 No esta el encargado  visitado
# 4                            06 Cerrado Definitivo  visitado
#
# [4751 rows x 28 columns]

# %% [markdown]
# # Exportación de archivo

# %%
b_file = fecha_entrega+"_nacional.xlsx"
joined_path2 = os.path.join(path, b_file)
nacional.to_excel(joined_path2,sheet_name=reporte, index=False)
