# %%
fecha_entrega = "1224" # <<<<<<< MODIFICAR DIARIOOOO

# %%
import pandas as pd
import numpy as np
import re
import os.path
from datetime import datetime

# %% [markdown]
# # Carga y preparación de [df]

# %%
# DataFrame
# "C:\Users\FernandoManuelGamino\Documents\4_cierre_dia_coordinadores\prueba\cedis.xlsx"
path = "../4_cierre_dia_coordinadores/"+fecha_entrega

# norte
a_file = "norte"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):
    norte = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass

# centro
a_file = "centro"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):
    centro = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass
    
# sur
a_file = "sur"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):    
    sur = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass

# puebla
a_file = "puebla"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):
    puebla = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass


# toluca
a_file = "toluca"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):    
    toluca = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass

# guadalajara
a_file = "guadalajara"+".xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):    
    guadalajara = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass

# leon
a_file = "leon.xlsx"
reporte = "RPT_Rejection_Rabbit"
joined_path = os.path.join(path, a_file)
if os.path.exists(joined_path):    
    leon = pd.read_excel(joined_path, sheet_name=reporte)
else:
    pass

# %%
# frames = [norte, centro, sur, puebla, toluca, guadalajara, leon]

frames = [toluca, leon, guadalajara, puebla]

nacional = pd.concat(frames)

# %%
nacional
# Out:
#     Logistic Distributor Delivery Route Delivery Name                  Region  \
# 0     Coordinador Toluca      Toluca-10     Toluca-10  Valle de Mexico Toluca
# 1     Coordinador Toluca      Toluca-10     Toluca-10  Valle de Mexico Toluca
# 2     Coordinador Toluca      Toluca-10     Toluca-10  Valle de Mexico Toluca
# 3     Coordinador Toluca      Toluca-10     Toluca-10  Valle de Mexico Toluca
# 4     Coordinador Toluca      Toluca-10     Toluca-10  Valle de Mexico Toluca
# ..                   ...            ...           ...                     ...
# 684   Coordinador puebla      Puebla-18     Puebla-18                  Puebla
# 685   Coordinador puebla      Puebla-18     Puebla-18                  Puebla
# 686   Coordinador puebla      Puebla-18     Puebla-18                  Puebla
# 687   Coordinador puebla      Puebla-18     Puebla-18                  Puebla
# 688   Coordinador puebla      Puebla-18     Puebla-18                  Puebla
#
#        City            Channel                       Sub Channel  \
# 0    Toluca  Canal Tradicional  Tiendas de abarrotes/misceláneas
# 1    Toluca  Canal Tradicional  Tiendas de abarrotes/misceláneas
# 2    Toluca  Canal Tradicional  Tiendas de abarrotes/misceláneas
# 3    Toluca  Canal Tradicional  Tiendas de abarrotes/misceláneas
# 4    Toluca  Canal Tradicional  Tiendas de abarrotes/misceláneas
# ..      ...                ...                               ...
# 684  Puebla  Canal Tradicional  Tiendas de abarrotes/misceláneas
# 685  Puebla  Canal Tradicional  Tiendas de abarrotes/misceláneas
# 686  Puebla  Canal Tradicional  Tiendas de abarrotes/misceláneas
# 687  Puebla  Canal Tradicional  Tiendas de abarrotes/misceláneas
# 688  Puebla  Canal Tradicional  Tiendas de abarrotes/misceláneas
#
#                           Customer Type  Store code            Store name  \
# 0    8_Tiendas de abarrotes/misceláneas  MX10600556     MISCELANEA MARTIN
# 1    8_Tiendas de abarrotes/misceláneas  MX10600876   TIENDA DE ABARROTES
# 2    8_Tiendas de abarrotes/misceláneas  MX10603976         MISCELANEA JC
# 3    8_Tiendas de abarrotes/misceláneas  MX10604000       MISCELANEA DANY
# 4    8_Tiendas de abarrotes/misceláneas  MX10605909     MISCELANEA CARMEN
# ..                                  ...         ...                   ...
# 684  8_Tiendas de abarrotes/misceláneas  RT00001879           CASA TEPEPA
# 685  8_Tiendas de abarrotes/misceláneas  RT00001889       ABARROTES BERRA
# 686  8_Tiendas de abarrotes/misceláneas  RT00002965               ANTONIA
# 687  8_Tiendas de abarrotes/misceláneas  RT00002979          JUAN SANCHEZ
# 688  8_Tiendas de abarrotes/misceláneas  RT00003832  MINI MARKET DON THEO
#
#      ...  Invoice Units Invoiced IEPS  Invoiced IVA  Net Sales Invoice Value  \
# 0    ...            NaN           NaN           NaN                      NaN
# 1    ...            NaN           NaN           NaN                      NaN
# 2    ...            NaN           NaN           NaN                      NaN
# 3    ...            NaN           NaN           NaN                      NaN
# 4    ...            NaN           NaN           NaN                      NaN
# ..   ...            ...           ...           ...                      ...
# 684  ...            8.0           NaN         28.42                      NaN
# 685  ...           16.0           NaN          0.00                      NaN
# 686  ...            6.0           NaN          0.00                      NaN
# 687  ...           12.0           NaN          0.00                      NaN
# 688  ...           60.0           NaN         30.63                      NaN
#
#      Rejection %  Rejection Value  Rejection % Qty Rejection Qty    Comment  \
# 0            NaN         -604.130              NaN           -55  ENTREGADO
# 1            NaN         -167.060              NaN           -16  ENTREGADO
# 2            NaN         -291.060              NaN           -14  ENTREGADO
# 3            NaN         -153.120              NaN           -24  ENTREGADO
# 4            NaN         -172.000              NaN            -3  ENTREGADO
# ..           ...              ...              ...           ...        ...
# 684     0.000010            0.002              0.0             0  ENTREGADO
# 685     0.000000            0.000              0.0             0  ENTREGADO
# 686     0.000000            0.000              0.0             0  ENTREGADO
# 687     0.000000            0.000              0.0             0  ENTREGADO
# 688     0.000008            0.004              0.0             0  ENTREGADO
#
#        Status
# 0    visitado
# 1    visitado
# 2    visitado
# 3    visitado
# 4    visitado
# ..        ...
# 684  visitado
# 685  visitado
# 686  visitado
# 687  visitado
# 688  visitado
#
# [1165 rows x 28 columns]

# %% [markdown]
# # Exportación de archivo

# %%
b_file = fecha_entrega+"_nacional.xlsx"
joined_path2 = os.path.join(path, b_file)
nacional.to_excel(joined_path2,sheet_name=reporte, index=False)
